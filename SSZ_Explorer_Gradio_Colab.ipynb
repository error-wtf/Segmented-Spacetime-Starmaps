# %% [markdown]
# # 🌌 SSZ StarMaps Explorer - Interactive Gradio App
#
# **Segmented Spacetime (SSZ) Gravitational Theory**
# *Casu & Wrede 2024*
#
# ---
#
# ## 📊 Features:
# - ✅ Interactive Physics Plots (Time Dilation, Radial Stretch, Domains)
# - ✅ Sharp Break Analysis at r_c
# - ✅ SSZ vs GR Comparison
# - ✅ Real Astronomical Objects
# - ✅ Domain-specific Piecewise Fits
#
# ---
#
# ## 🚀 Run this notebook to start the Gradio app!

# %%
# 1️⃣ Clone Repository
# !git clone https://github.com/error-wtf/Segmented-Spacetime-Starmaps.git
# %cd Segmented-Spacetime-Starmaps

# %%
# 2️⃣ Install Dependencies
# !pip install -q gradio matplotlib numpy scipy pandas astropy astroquery

# %%
# 3️⃣ Import Core SSZ Functions from PAPER-RESTORED
import sys
sys.path.insert(0, '/content/Segmented-Spacetime-Starmaps')
sys.path.insert(0, '/content/Segmented-Spacetime-Starmaps/ssz_explorer')

# Import PAPER-RESTORED functions if available
try:
    # Try to add PAPER-RESTORED path
    import os
    paper_path = '/content/PAPER-RESTORED'
    if os.path.exists(paper_path):
        sys.path.insert(0, paper_path)
    print("✅ Paths configured")
except:
    print("⚠️ PAPER-RESTORED not found - using embedded SSZ functions")

# %%
# 4️⃣ Launch Gradio App with PUBLIC LINK
import subprocess
import sys

# Set environment for Colab
import os
os.environ['GRADIO_SERVER_NAME'] = '0.0.0.0'
os.environ['GRADIO_SERVER_PORT'] = '7860'

print("🚀 Starting SSZ Explorer Gradio App...\n")
print("📍 The PUBLIC LINK will appear below in ~30 seconds\n")
print("🌐 Look for: 'Running on public URL: https://xxxxx.gradio.live'\n")
print("="*60)

# Run the Gradio app
# !python ssz_explorer/gradio_app_complete.py

# %% [markdown]
# ---
#
# ## 📖 How to Use:
#
# 1. **Run ALL cells above** (Runtime → Run all)
# 2. **Wait ~30 seconds** for Gradio to start
# 3. **Click the PUBLIC LINK** that appears (looks like `https://xxxxx.gradio.live`)
# 4. **Explore the Physics Plots!**
#
# ---
#
# ## 🎯 Features in the App:
#
# ### **📊 Time Dilation Plot:**
# - Shows **A(r) = D(r)·(1-r_s/r)** for SSZ
# - Compares with **GR: A(r) = 1-r_s/r**
# - **Yellow marker**: Intersection point SSZ ∩ GR
# - **Sharp break** at r_c with domain shading
#
# ### **📈 Segmentation Field γ(r):**
# - Shows **γ(r) = 1 - α·exp(-(r/r_c)²)**
# - **Collapse Rate** C(r) = -dγ/dr in second panel
# - **Piecewise fits** for g₂ (collapse) and g₁ (stable)
#
# ### **🌐 Combined Analysis:**
# - 4-panel comparison
# - All domains visualized
#
# ---
#
# ## 🔗 Links:
#
# - **GitHub:** https://github.com/error-wtf/Segmented-Spacetime-Starmaps
# - **License:** Anti-Capitalist Software License v1.4
# - **Contact:** mail@error.wtf
#
# ---
#
# *© 2024 Carmen Wrede & Lino Casu*
